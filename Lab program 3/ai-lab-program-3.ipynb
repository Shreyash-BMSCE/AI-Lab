# %% [markdown]
# # 8 Puzzle Problem

# %% [markdown]
# BMS College of Engineering - Dr Kavitha Sooda <br />
# BMS College of Engineering - Dr Nagarathna N <br />
# BMS College of Engineering - Prof G R Asha  <br />
# ##### Class 5C

# %% [markdown]
# ## Objective
#  Given a 3×3 board with 8 tiles and one empty space
#  - Move the numbers around to match the final configuration using the empty spot
#  - You can slide the numbers from above, below, left and right tiles into the empty space.
# ![](https://media.geeksforgeeks.org/wp-content/uploads/puzzle8init.jpg)

# %% [markdown]
# Try and use a Brute Force Algorithms
#
# ![](https://media.geeksforgeeks.org/wp-content/uploads/puzzle-1.jpg)

# %%
# Bredth first search in search of target - Using Brute Force Algorithms

def bfs(src,target):
    # Use brute force technique
    arr = [src]
    c = 0
    while arr:
        c += 1                                                                            
        if arr[0] == target:                             
            return True
        arr += possible_moves(arr[0])                    
        arr.pop(0)                                                                    
    return False

# %%
# Find Possible Moves
def possible_moves(state): 
    b = state.index(-1)
    
    d = []
    
  
                                    
    if b-3 in range(9):
        d.append('u')
    if b+3 in range(9):
        d.append('d')
    if b not in [0,3,6]: 
        d.append('l')
    if b not in [2,5,8]: 
        d.append('r')
    
    
    # If direction is possible then add state to move
    pos_moves = []
    
    # for all possible directions find the state if that move is played
    ### Jump to gen function to generate all possible moves in the given directions
    for move in d:
        pos_moves.append(gen(state,move,b))
        
    return pos_moves

# %%
# Generate move for given direction
def gen(state, m, b):
    temp = state.copy()                                
    
    # if move is to slide empty spot to the left and so on
    if m == 'u': temp[b], temp[b-3] = temp[b-3], temp[b]
    if m == 'd': temp[b], temp[b+3] = temp[b+3], temp[b]
    if m == 'l': temp[b], temp[b-1] = temp[b-1], temp[b]
    if m == 'r': temp[b], temp[b+1] = temp[b+1], temp[b]
    
    # return new state with tested move to later check if "src == target"
    return temp

# %%
#Test 1
src = [1,2,3,-1,4,5,6,7,8]
target = [1,2,3,4,5,-1,6,7,8]         
       


bfs(src, target)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-4300740b4934> in <module>
#       5
#       6
# ----> 7 bfs(src, target)
#
# <ipython-input-1-3fa5a58581bd> in bfs(src, target)
#       9         if arr[0] == target:
#      10             return True
# ---> 11         arr += possible_moves(arr[0])
#      12         arr.pop(0)
#      13     return False
#
# <ipython-input-2-ff30d98698ed> in possible_moves(state)
#      23     ### Jump to gen function to generate all possible moves in the given directions
#      24     for move in d:
# ---> 25         pos_moves.append(gen(state,move,b))
#      26
#      27     return pos_moves
#
# <ipython-input-3-e7669f34254b> in gen(state, direction, blank_spot)
#       4
#       5     # if move is to slide empty spot to the left and so on
# ----> 6     if m == 'u': temp[b], temp[b-3] = temp[b-3], temp[b]
#       7     if m == 'd': temp[b], temp[b+3] = temp[b+3], temp[b]
#       8     if m == 'l': temp[b], temp[b-1] = temp[b-1], temp[b]
#
# NameError: name 'm' is not defined

# %%
# Test 2
src = [1,2,3,-1,4,5,6,7,8] 
target=[1,2,3,6,4,5,-1,7,8]



bfs(src, target)

# %% [markdown]
# # Challenge

# %% [markdown]
# 1. Change the above functions to add memory so the a site already checked isnt visited again
# 2. Try another brute force algorithm to find the solution
